# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date, 
                          "Current Description": city_description})
    
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | waipawa
# Processing Record 6 of Set 1 | geraldton
# Processing Record 7 of Set 1 | vardo
# Processing Record 8 of Set 1 | kushmurun
# Processing Record 9 of Set 1 | sueyoshi
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | evanston
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | nishihara
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | pangnirtung
# Processing Record 18 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | lingao
# Processing Record 25 of Set 1 | pecanha
# Processing Record 26 of Set 1 | mount isa
# Processing Record 27 of Set 1 | nha trang
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | shingu
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | faya
# Processing Record 32 of Set 1 | pringsewu
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | vyazma
# Processing Record 36 of Set 1 | ostrovskoye
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | lata
# Processing Record 40 of Set 1 | maceio
# Processing Record 41 of Set 1 | sitka
# Processing Record 42 of Set 1 | vestmannaeyjar
# Processing Record 43 of Set 1 | adrar
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | walvis bay
# Processing Record 47 of Set 1 | izhma
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | ostrovnoy
# Processing Record 50 of Set 1 | cloquet
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | tabuk
# Processing Record 5 of Set 2 | yerbogachen
# Processing Record 6 of Set 2 | tadine
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | bani walid
# Processing Record 9 of Set 2 | padang
# Processing Record 10 of Set 2 | marsabit
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | leningradskiy
# Processing Record 13 of Set 2 | saint peter
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | goderich
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | maykain
# City not found. Skipping...
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | ponorogo
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | badiraguato
# Processing Record 22 of Set 2 | la union
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 2 | dunkirk
# Processing Record 26 of Set 2 | henties bay
# Processing Record 27 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | mehran
# Processing Record 29 of Set 2 | la ronge
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | nome
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | ileza
# Processing Record 34 of Set 2 | lorengau
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | gat
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | klaksvik
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | byron bay
# Processing Record 42 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | sterling
# Processing Record 45 of Set 2 | camopi
# Processing Record 46 of Set 2 | ushtobe
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | mbandaka
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | manado
# Processing Record 1 of Set 3 | olinda
# Processing Record 2 of Set 3 | baiao
# Processing Record 3 of Set 3 | jingdezhen
# Processing Record 4 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 3 | korla
# Processing Record 6 of Set 3 | merritt island
# Processing Record 7 of Set 3 | cabo san lucas
# Processing Record 8 of Set 3 | cumra
# Processing Record 9 of Set 3 | salinopolis
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | namatanai
# Processing Record 12 of Set 3 | mataura
# Processing Record 13 of Set 3 | jumla
# Processing Record 14 of Set 3 | atbasar
# Processing Record 15 of Set 3 | port elizabeth
# Processing Record 16 of Set 3 | fairbanks
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | richards bay
# Processing Record 22 of Set 3 | portland
# Processing Record 23 of Set 3 | sal rei
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | altamira
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | coquimbo
# Processing Record 28 of Set 3 | rinconada
# Processing Record 29 of Set 3 | mecca
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | mama
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 35 of Set 3 | muroto
# Processing Record 36 of Set 3 | pithoragarh
# Processing Record 37 of Set 3 | rapid valley
# Processing Record 38 of Set 3 | atar
# Processing Record 39 of Set 3 | nelson bay
# Processing Record 40 of Set 3 | alice springs
# Processing Record 41 of Set 3 | verkhnevilyuysk
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | dickinson
# Processing Record 44 of Set 3 | yellowknife
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | katsuura
# Processing Record 47 of Set 3 | traismauer
# Processing Record 48 of Set 3 | zalantun
# Processing Record 49 of Set 3 | kharp
# Processing Record 50 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | inhambane
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | coolum beach
# Processing Record 6 of Set 4 | mercedes
# Processing Record 7 of Set 4 | nova gradiska
# Processing Record 8 of Set 4 | husavik
# Processing Record 9 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | isla vista
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | katherine
# Processing Record 14 of Set 4 | slonim
# Processing Record 15 of Set 4 | timra
# Processing Record 16 of Set 4 | kearney
# Processing Record 17 of Set 4 | ahtopol
# Processing Record 18 of Set 4 | grande-riviere
# City not found. Skipping...
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | maragogi
# Processing Record 21 of Set 4 | pochutla
# Processing Record 22 of Set 4 | centralia
# Processing Record 23 of Set 4 | valparaiso
# Processing Record 24 of Set 4 | saskylakh
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | sungaipenuh
# Processing Record 28 of Set 4 | muros
# Processing Record 29 of Set 4 | urubicha
# Processing Record 30 of Set 4 | beringovskiy
# Processing Record 31 of Set 4 | kaitangata
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | ancud
# Processing Record 34 of Set 4 | yabrud
# Processing Record 35 of Set 4 | necochea
# Processing Record 36 of Set 4 | khani
# Processing Record 37 of Set 4 | labrea
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | khandyga
# Processing Record 40 of Set 4 | gemena
# Processing Record 41 of Set 4 | jibuti
# Processing Record 42 of Set 4 | gidam
# Processing Record 43 of Set 4 | boddam
# Processing Record 44 of Set 4 | praia da vitoria
# Processing Record 45 of Set 4 | makushino
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 4 | tura
# Processing Record 48 of Set 4 | port augusta
# Processing Record 49 of Set 4 | kapoeta
# Processing Record 50 of Set 4 | batavia
# Processing Record 1 of Set 5 | rincon
# Processing Record 2 of Set 5 | lokomotivnyy
# Processing Record 3 of Set 5 | san cristobal
# Processing Record 4 of Set 5 | arraial do cabo
# Processing Record 5 of Set 5 | do rud
# City not found. Skipping...
# Processing Record 6 of Set 5 | mayo
# Processing Record 7 of Set 5 | mandera
# Processing Record 8 of Set 5 | plettenberg bay
# Processing Record 9 of Set 5 | mandalgovi
# Processing Record 10 of Set 5 | opuwo
# Processing Record 11 of Set 5 | hermanus
# Processing Record 12 of Set 5 | grand-lahou
# Processing Record 13 of Set 5 | tiznit
# Processing Record 14 of Set 5 | moron
# Processing Record 15 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | anderson
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | karratha
# Processing Record 20 of Set 5 | balkhash
# Processing Record 21 of Set 5 | chumikan
# Processing Record 22 of Set 5 | myitkyina
# Processing Record 23 of Set 5 | thanh hoa
# Processing Record 24 of Set 5 | gogrial
# Processing Record 25 of Set 5 | havelock
# Processing Record 26 of Set 5 | inhapim
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | magdagachi
# Processing Record 29 of Set 5 | tairua
# Processing Record 30 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 5 | maniitsoq
# Processing Record 32 of Set 5 | antalaha
# Processing Record 33 of Set 5 | kenai
# Processing Record 34 of Set 5 | hamilton
# Processing Record 35 of Set 5 | rumphi
# Processing Record 36 of Set 5 | sabinas hidalgo
# Processing Record 37 of Set 5 | stromness
# Processing Record 38 of Set 5 | puerto escondido
# Processing Record 39 of Set 5 | shimoda
# Processing Record 40 of Set 5 | cayenne
# Processing Record 41 of Set 5 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 42 of Set 5 | gillette
# Processing Record 43 of Set 5 | vila velha
# Processing Record 44 of Set 5 | toungoo
# City not found. Skipping...
# Processing Record 45 of Set 5 | sampit
# Processing Record 46 of Set 5 | port lincoln
# Processing Record 47 of Set 5 | samandag
# Processing Record 48 of Set 5 | dryden
# Processing Record 49 of Set 5 | iqaluit
# Processing Record 50 of Set 5 | san patricio
# Processing Record 1 of Set 6 | cockburn town
# Processing Record 2 of Set 6 | athabasca
# Processing Record 3 of Set 6 | berlevag
# Processing Record 4 of Set 6 | santiago
# Processing Record 5 of Set 6 | batagay-alyta
# Processing Record 6 of Set 6 | dunedin
# Processing Record 7 of Set 6 | san jose
# Processing Record 8 of Set 6 | barrow
# Processing Record 9 of Set 6 | pforzheim
# Processing Record 10 of Set 6 | samaipata
# Processing Record 11 of Set 6 | bonavista
# Processing Record 12 of Set 6 | sur
# Processing Record 13 of Set 6 | killarney
# Processing Record 14 of Set 6 | camana
# Processing Record 15 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 6 | kavaratti
# Processing Record 17 of Set 6 | kaka
# Processing Record 18 of Set 6 | pisco
# Processing Record 19 of Set 6 | sazonovo
# Processing Record 20 of Set 6 | lundazi
# Processing Record 21 of Set 6 | sarangani
# Processing Record 22 of Set 6 | saint-francois
# Processing Record 23 of Set 6 | torbay
# Processing Record 24 of Set 6 | grootfontein
# Processing Record 25 of Set 6 | kihei
# Processing Record 26 of Set 6 | viedma
# Processing Record 27 of Set 6 | ialibu
# Processing Record 28 of Set 6 | barcelos
# Processing Record 29 of Set 6 | swan river
# Processing Record 30 of Set 6 | helong
# Processing Record 31 of Set 6 | saint-paul
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | tyret pervaya
# Processing Record 34 of Set 6 | fort nelson
# Processing Record 35 of Set 6 | severnyy-kospashskiy
# Processing Record 36 of Set 6 | quatre cocos
# Processing Record 37 of Set 6 | lavrentiya
# Processing Record 38 of Set 6 | biak
# Processing Record 39 of Set 6 | margate
# Processing Record 40 of Set 6 | oranjemund
# Processing Record 41 of Set 6 | mar del plata
# Processing Record 42 of Set 6 | kyela
# Processing Record 43 of Set 6 | vao
# Processing Record 44 of Set 6 | tingrela
# City not found. Skipping...
# Processing Record 45 of Set 6 | duverge
# Processing Record 46 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 6 | ketchikan
# Processing Record 48 of Set 6 | grindavik
# Processing Record 49 of Set 6 | kargasok
# Processing Record 50 of Set 6 | sri aman
# Processing Record 1 of Set 7 | omsukchan
# Processing Record 2 of Set 7 | riyadh
# Processing Record 3 of Set 7 | burnie
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | nur
# Processing Record 6 of Set 7 | naushki
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | pacific grove
# Processing Record 9 of Set 7 | hirara
# Processing Record 10 of Set 7 | soe
# Processing Record 11 of Set 7 | kieta
# Processing Record 12 of Set 7 | lufilufi
# Processing Record 13 of Set 7 | thunder bay
# Processing Record 14 of Set 7 | polunochnoye
# Processing Record 15 of Set 7 | impfondo
# Processing Record 16 of Set 7 | ahipara
# Processing Record 17 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 7 | pudozh
# Processing Record 19 of Set 7 | flagstaff
# Processing Record 20 of Set 7 | half moon bay
# Processing Record 21 of Set 7 | praia
# Processing Record 22 of Set 7 | hasaki
# Processing Record 23 of Set 7 | ipameri
# Processing Record 24 of Set 7 | nanortalik
# Processing Record 25 of Set 7 | zyryanka
# Processing Record 26 of Set 7 | xghajra
# City not found. Skipping...
# Processing Record 27 of Set 7 | kyren
# Processing Record 28 of Set 7 | raga
# Processing Record 29 of Set 7 | krasnoselkup
# Processing Record 30 of Set 7 | victoria
# Processing Record 31 of Set 7 | haines junction
# Processing Record 32 of Set 7 | nalut
# Processing Record 33 of Set 7 | kibala
# Processing Record 34 of Set 7 | rock sound
# Processing Record 35 of Set 7 | beckley
# Processing Record 36 of Set 7 | lompoc
# Processing Record 37 of Set 7 | kampene
# Processing Record 38 of Set 7 | pastavy
# Processing Record 39 of Set 7 | caratinga
# Processing Record 40 of Set 7 | rawson
# Processing Record 41 of Set 7 | codrington
# Processing Record 42 of Set 7 | vila franca do campo
# Processing Record 43 of Set 7 | pilibhit
# Processing Record 44 of Set 7 | volchikha
# Processing Record 45 of Set 7 | san quintin
# Processing Record 46 of Set 7 | waddan
# Processing Record 47 of Set 7 | paranaiba
# Processing Record 48 of Set 7 | mahebourg
# Processing Record 49 of Set 7 | greenwood
# Processing Record 50 of Set 7 | santa lucia
# Processing Record 1 of Set 8 | nova aurora
# Processing Record 2 of Set 8 | alghero
# Processing Record 3 of Set 8 | salinas
# Processing Record 4 of Set 8 | kerouane
# Processing Record 5 of Set 8 | vostok
# Processing Record 6 of Set 8 | san andres
# Processing Record 7 of Set 8 | bahawalpur
# Processing Record 8 of Set 8 | lensk
# Processing Record 9 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 8 | pangkalanbuun
# Processing Record 12 of Set 8 | linxia
# Processing Record 13 of Set 8 | zonguldak
# Processing Record 14 of Set 8 | gwadar
# Processing Record 15 of Set 8 | touros
# Processing Record 16 of Set 8 | zabid
# Processing Record 17 of Set 8 | vanavara
# Processing Record 18 of Set 8 | yaan
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | fortuna
# Processing Record 21 of Set 8 | skjervoy
# Processing Record 22 of Set 8 | cairns
# Processing Record 23 of Set 8 | dawlatabad
# Processing Record 24 of Set 8 | dwarka
# Processing Record 25 of Set 8 | la orilla
# Processing Record 26 of Set 8 | algiers
# Processing Record 27 of Set 8 | baturaja
# Processing Record 28 of Set 8 | pedra branca
# Processing Record 29 of Set 8 | taltal
# Processing Record 30 of Set 8 | raudeberg
# Processing Record 31 of Set 8 | ayan
# Processing Record 32 of Set 8 | lons-le-saunier
# Processing Record 33 of Set 8 | macenta
# Processing Record 34 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 8 | vestmanna
# Processing Record 36 of Set 8 | tezu
# Processing Record 37 of Set 8 | ucluelet
# Processing Record 38 of Set 8 | bacolod
# Processing Record 39 of Set 8 | santa quiteria
# Processing Record 40 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 8 | constitucion
# Processing Record 42 of Set 8 | bagdarin
# Processing Record 43 of Set 8 | sakakah
# Processing Record 44 of Set 8 | anisoc
# Processing Record 45 of Set 8 | tornio
# Processing Record 46 of Set 8 | rio gallegos
# Processing Record 47 of Set 8 | salalah
# Processing Record 48 of Set 8 | drumheller
# Processing Record 49 of Set 8 | saldanha
# Processing Record 50 of Set 8 | ardakan
# Processing Record 1 of Set 9 | taoudenni
# Processing Record 2 of Set 9 | sorland
# Processing Record 3 of Set 9 | saint-pierre
# Processing Record 4 of Set 9 | samarai
# Processing Record 5 of Set 9 | coahuayana
# Processing Record 6 of Set 9 | sao filipe
# Processing Record 7 of Set 9 | menongue
# Processing Record 8 of Set 9 | ghanzi
# Processing Record 9 of Set 9 | tarko-sale
# Processing Record 10 of Set 9 | kaliua
# Processing Record 11 of Set 9 | college
# Processing Record 12 of Set 9 | mahon
# Processing Record 13 of Set 9 | lasa
# Processing Record 14 of Set 9 | kudahuvadhoo
# Processing Record 15 of Set 9 | baijiantan
# Processing Record 16 of Set 9 | talavera de la reina
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 9 | siyabuswa
# Processing Record 20 of Set 9 | uberaba
# Processing Record 21 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 22 of Set 9 | cabedelo
# Processing Record 23 of Set 9 | kirakira
# Processing Record 24 of Set 9 | villa vazquez
# City not found. Skipping...
# Processing Record 25 of Set 9 | zaraza
# Processing Record 26 of Set 9 | minnedosa
# Processing Record 27 of Set 9 | pachuca
# Processing Record 28 of Set 9 | khorramshahr
# Processing Record 29 of Set 9 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 9 | aasiaat
# Processing Record 32 of Set 9 | ventspils
# Processing Record 33 of Set 9 | chapais
# Processing Record 34 of Set 9 | liwale
# Processing Record 35 of Set 9 | ust-nera
# Processing Record 36 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 9 | vallenar
# Processing Record 38 of Set 9 | mount gambier
# Processing Record 39 of Set 9 | sorong
# Processing Record 40 of Set 9 | talnakh
# Processing Record 41 of Set 9 | ust-ilimsk
# Processing Record 42 of Set 9 | port-cartier
# Processing Record 43 of Set 9 | olafsvik
# Processing Record 44 of Set 9 | la baule-escoublac
# Processing Record 45 of Set 9 | birao
# Processing Record 46 of Set 9 | lagoa
# Processing Record 47 of Set 9 | tartki
# City not found. Skipping...
# Processing Record 48 of Set 9 | russell
# Processing Record 49 of Set 9 | belaya gora
# Processing Record 50 of Set 9 | jambi
# Processing Record 1 of Set 10 | crib point
# Processing Record 2 of Set 10 | buala
# Processing Record 3 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 10 | sabha
# Processing Record 5 of Set 10 | ponta delgada
# Processing Record 6 of Set 10 | cap malheureux
# Processing Record 7 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 8 of Set 10 | pilar do sul
# Processing Record 9 of Set 10 | paris
# Processing Record 10 of Set 10 | halifax
# Processing Record 11 of Set 10 | careiro da varzea
# Processing Record 12 of Set 10 | mortka
# Processing Record 13 of Set 10 | laguna
# Processing Record 14 of Set 10 | sembe
# Processing Record 15 of Set 10 | vaitape
# Processing Record 16 of Set 10 | meulaboh
# Processing Record 17 of Set 10 | sheridan
# Processing Record 18 of Set 10 | portree
# Processing Record 19 of Set 10 | namibe
# Processing Record 20 of Set 10 | honiara
# Processing Record 21 of Set 10 | bathsheba
# Processing Record 22 of Set 10 | wapi pathum
# Processing Record 23 of Set 10 | ossora
# Processing Record 24 of Set 10 | udachnyy
# Processing Record 25 of Set 10 | jiexiu
# Processing Record 26 of Set 10 | terrace bay
# Processing Record 27 of Set 10 | prince rupert
# Processing Record 28 of Set 10 | gasan
# Processing Record 29 of Set 10 | araouane
# Processing Record 30 of Set 10 | balkanabat
# Processing Record 31 of Set 10 | moose jaw
# Processing Record 32 of Set 10 | novyy nekouz
# Processing Record 33 of Set 10 | sept-iles
# Processing Record 34 of Set 10 | naze
# Processing Record 35 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 36 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 37 of Set 10 | zhicheng
# Processing Record 38 of Set 10 | mogadishu
# Processing Record 39 of Set 10 | xining
# Processing Record 40 of Set 10 | tari
# Processing Record 41 of Set 10 | camacha
# Processing Record 42 of Set 10 | harper
# Processing Record 43 of Set 10 | oistins
# Processing Record 44 of Set 10 | sailana
# Processing Record 45 of Set 10 | chicama
# Processing Record 46 of Set 10 | nuuk
# Processing Record 47 of Set 10 | holme
# Processing Record 48 of Set 10 | pec
# Processing Record 49 of Set 10 | jishou
# Processing Record 50 of Set 10 | puerto colombia
# Processing Record 1 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 11 | dong hoi
# Processing Record 3 of Set 11 | japura
# Processing Record 4 of Set 11 | lazaro cardenas
# Processing Record 5 of Set 11 | novotroitsk
# Processing Record 6 of Set 11 | lipin bor
# Processing Record 7 of Set 11 | concepcion del oro
# Processing Record 8 of Set 11 | la palma
# Processing Record 9 of Set 11 | west bay
# Processing Record 10 of Set 11 | oyama
# Processing Record 11 of Set 11 | grand gaube
# Processing Record 12 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 11 | najran
# Processing Record 14 of Set 11 | tecoanapa
# Processing Record 15 of Set 11 | eagle pass
# Processing Record 16 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 17 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 11 | dahra
# Processing Record 19 of Set 11 | koping
# Processing Record 20 of Set 11 | bosaso
# Processing Record 21 of Set 11 | hay river
# Processing Record 22 of Set 11 | sisimiut
# Processing Record 23 of Set 11 | aranda de duero
# Processing Record 24 of Set 11 | avera
# Processing Record 25 of Set 11 | aginskoye
# Processing Record 26 of Set 11 | puerto baquerizo moreno
# Processing Record 27 of Set 11 | itoman
# Processing Record 28 of Set 11 | escarcega
# Processing Record 29 of Set 11 | shu
# Processing Record 30 of Set 11 | lawton
# Processing Record 31 of Set 11 | puerto leguizamo
# Processing Record 32 of Set 11 | manaure
# Processing Record 33 of Set 11 | ojinaga
# Processing Record 34 of Set 11 | tual
# Processing Record 35 of Set 11 | yar-sale
# Processing Record 36 of Set 11 | sidi ali
# Processing Record 37 of Set 11 | cabras
# Processing Record 38 of Set 11 | gamba
# Processing Record 39 of Set 11 | port macquarie
# Processing Record 40 of Set 11 | makakilo city
# Processing Record 41 of Set 11 | kyzyl-suu
# Processing Record 42 of Set 11 | les cayes
# Processing Record 43 of Set 11 | sao joao da barra
# Processing Record 44 of Set 11 | vanderhoof
# Processing Record 45 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 11 | calama
# Processing Record 47 of Set 11 | ughelli
# Processing Record 48 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 11 | watertown
# Processing Record 50 of Set 11 | sao jose da coroa grande
# Processing Record 1 of Set 12 | hualmay
# Processing Record 2 of Set 12 | marechal candido rondon
# Processing Record 3 of Set 12 | durant
# Processing Record 4 of Set 12 | acapulco
# Processing Record 5 of Set 12 | pemangkat
# Processing Record 6 of Set 12 | mehamn
# Processing Record 7 of Set 12 | masuguru
# Processing Record 8 of Set 12 | cururupu
# Processing Record 9 of Set 12 | sesvete
# Processing Record 10 of Set 12 | port hawkesbury
# Processing Record 11 of Set 12 | rocha
# Processing Record 12 of Set 12 | corumba
# Processing Record 13 of Set 12 | mazara del vallo
# Processing Record 14 of Set 12 | quelimane
# Processing Record 15 of Set 12 | ipinda
# Processing Record 16 of Set 12 | nizwa
# Processing Record 17 of Set 12 | kununurra
# Processing Record 18 of Set 12 | nyimba
# Processing Record 19 of Set 12 | alibog
# City not found. Skipping...
# Processing Record 20 of Set 12 | santa cruz de la palma
# Processing Record 21 of Set 12 | lethem
# Processing Record 22 of Set 12 | ilebo
# Processing Record 23 of Set 12 | tilichiki
# Processing Record 24 of Set 12 | nampula
# Processing Record 25 of Set 12 | campoverde
# Processing Record 26 of Set 12 | estevan
# Processing Record 27 of Set 12 | chom bung
# City not found. Skipping...
# Processing Record 28 of Set 12 | lashio
# Processing Record 29 of Set 12 | deputatskiy
# Processing Record 30 of Set 12 | srednekolymsk
# Processing Record 31 of Set 12 | mubi
# Processing Record 32 of Set 12 | luebo
# Processing Record 33 of Set 12 | zhigansk
# Processing Record 34 of Set 12 | lakes entrance
# Processing Record 35 of Set 12 | jiwani
# Processing Record 36 of Set 12 | rorvik
# Processing Record 37 of Set 12 | marsh harbour
# Processing Record 38 of Set 12 | sabaudia
# Processing Record 39 of Set 12 | poum
# Processing Record 40 of Set 12 | elizabeth city
# Processing Record 41 of Set 12 | garowe
# Processing Record 42 of Set 12 | naliya
# Processing Record 43 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 12 | preeceville
# Processing Record 45 of Set 12 | roald
# Processing Record 46 of Set 12 | maralal
# Processing Record 47 of Set 12 | sao felix do xingu
# Processing Record 48 of Set 12 | saint-joseph
# Processing Record 49 of Set 12 | asau
# Processing Record 50 of Set 12 | karaton
# Processing Record 1 of Set 13 | huambo
# Processing Record 2 of Set 13 | puerto narino
# Processing Record 3 of Set 13 | belyy yar
# Processing Record 4 of Set 13 | porto recanati
# Processing Record 5 of Set 13 | barreirinha
# Processing Record 6 of Set 13 | keokuk
# Processing Record 7 of Set 13 | wenling
# Processing Record 8 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 13 | poya
# Processing Record 10 of Set 13 | hamada
# Processing Record 11 of Set 13 | padra
# Processing Record 12 of Set 13 | savonlinna
# Processing Record 13 of Set 13 | ust-omchug
# Processing Record 14 of Set 13 | kantabanji
# Processing Record 15 of Set 13 | rabo de peixe
# Processing Record 16 of Set 13 | merritt
# Processing Record 17 of Set 13 | mulchen
# Processing Record 18 of Set 13 | lokken verk
# City not found. Skipping...
# Processing Record 19 of Set 13 | maningrida
# Processing Record 20 of Set 13 | owatonna
# Processing Record 21 of Set 13 | evensk
# Processing Record 22 of Set 13 | todos santos
# Processing Record 23 of Set 13 | jijiang
# Processing Record 24 of Set 13 | surt
# Processing Record 25 of Set 13 | srivardhan
# Processing Record 26 of Set 13 | daru
# Processing Record 27 of Set 13 | matara
# Processing Record 28 of Set 13 | bolu
# Processing Record 29 of Set 13 | koboldo
# City not found. Skipping...
# Processing Record 30 of Set 13 | conde
# Processing Record 31 of Set 13 | bac lieu
# Processing Record 32 of Set 13 | male
# Processing Record 33 of Set 13 | port hedland
# Processing Record 34 of Set 13 | jiblah
# Processing Record 35 of Set 13 | mukhtolovo
# Processing Record 36 of Set 13 | rio grande
# Processing Record 37 of Set 13 | baoning
# Processing Record 38 of Set 13 | fort thomas
# Processing Record 39 of Set 13 | anchorage
# Processing Record 40 of Set 13 | vicuna
# Processing Record 41 of Set 13 | broken hill
# Processing Record 42 of Set 13 | marawi
# Processing Record 43 of Set 13 | whitehorse
# Processing Record 44 of Set 13 | porto walter
# Processing Record 45 of Set 13 | hami
# Processing Record 46 of Set 13 | aksha
# Processing Record 47 of Set 13 | phonhong
# Processing Record 48 of Set 13 | dingle
# Processing Record 49 of Set 13 | nantucket
# Processing Record 50 of Set 13 | mizusawa
# Processing Record 1 of Set 14 | lerwick
# Processing Record 2 of Set 14 | bantou
# Processing Record 3 of Set 14 | saint anthony
# Processing Record 4 of Set 14 | arlit
# Processing Record 5 of Set 14 | victor harbor
# Processing Record 6 of Set 14 | umm kaddadah
# Processing Record 7 of Set 14 | bauchi
# Processing Record 8 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 14 | jalu
# Processing Record 10 of Set 14 | lima
# Processing Record 11 of Set 14 | bethanien
# Processing Record 12 of Set 14 | moose factory
# Processing Record 13 of Set 14 | shakawe
# Processing Record 14 of Set 14 | pevek
# Processing Record 15 of Set 14 | huainan
# Processing Record 16 of Set 14 | graham
# Processing Record 17 of Set 14 | pryozerne
# Processing Record 18 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 14 | chalon-sur-saone
# Processing Record 20 of Set 14 | wattegama
# Processing Record 21 of Set 14 | ganzhou
# Processing Record 22 of Set 14 | muswellbrook
# Processing Record 23 of Set 14 | qaqortoq
# Processing Record 24 of Set 14 | senanga
# Processing Record 25 of Set 14 | sola
# Processing Record 26 of Set 14 | varnamo
# Processing Record 27 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 28 of Set 14 | nicoya
# Processing Record 29 of Set 14 | kargil
# Processing Record 30 of Set 14 | dzhebariki-khaya
# Processing Record 31 of Set 14 | manoel urbano
# Processing Record 32 of Set 14 | umm lajj
# Processing Record 33 of Set 14 | westport
# Processing Record 34 of Set 14 | xitla
# City not found. Skipping...
# Processing Record 35 of Set 14 | resistencia
# Processing Record 36 of Set 14 | uchiza
# Processing Record 37 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 38 of Set 14 | rosendal
# Processing Record 39 of Set 14 | kingman
# Processing Record 40 of Set 14 | kuybysheve
# Processing Record 41 of Set 14 | kristinehamn
# Processing Record 42 of Set 14 | quthing
# Processing Record 43 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 14 | pahrump
# Processing Record 45 of Set 14 | hobyo
# Processing Record 46 of Set 14 | mackay
# Processing Record 47 of Set 14 | zheshart
# Processing Record 48 of Set 14 | ciudad bolivar
# Processing Record 49 of Set 14 | badnawar
# Processing Record 50 of Set 14 | annau
# Processing Record 1 of Set 15 | alta floresta
# Processing Record 2 of Set 15 | vagay
# Processing Record 3 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 15 | ixtapa
# Processing Record 5 of Set 15 | stykkisholmur
# Processing Record 6 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 15 | te anau
# Processing Record 8 of Set 15 | urusha
# Processing Record 9 of Set 15 | killybegs
# Processing Record 10 of Set 15 | tautira
# Processing Record 11 of Set 15 | ahuimanu
# Processing Record 12 of Set 15 | honningsvag
# Processing Record 13 of Set 15 | linhares
# Processing Record 14 of Set 15 | san policarpo
# Processing Record 15 of Set 15 | lapua
# Processing Record 16 of Set 15 | oda
# Processing Record 17 of Set 15 | jacqueville
# Processing Record 18 of Set 15 | boksitogorsk
# Processing Record 19 of Set 15 | thinadhoo
# Processing Record 20 of Set 15 | bongandanga
# Processing Record 21 of Set 15 | kayerkan
# Processing Record 22 of Set 15 | maihar
# Processing Record 23 of Set 15 | kalamare
# Processing Record 24 of Set 15 | palmas
# Processing Record 25 of Set 15 | auki
# Processing Record 26 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 15 | ostersund
# Processing Record 28 of Set 15 | ranong
# Processing Record 29 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 30 of Set 15 | guerrero negro
# Processing Record 31 of Set 15 | chara
# Processing Record 32 of Set 15 | stornoway
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 669

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Bengkulu  -3.8004  102.2655     85.44        62          99        6.55
# 1     Faanui -16.4833 -151.7500     80.38        78          81       15.37
# 2       Hilo  19.7297 -155.0900     76.28        85          90        4.61
# 3    Waipawa -41.4122  175.5153     56.03        88         100        5.68
# 4  Geraldton -28.7667  114.6000     70.21        64          40       18.41
# 5      Vardo  70.3705   31.1107     52.00        71          40        4.61
# 6  Kushmurun  52.4503   64.6311     80.69        30          27        2.33
# 7   Sueyoshi  31.6500  131.0167     81.57        75          81        5.79
# 8   Evanston  42.0411  -87.6901     74.97        51           1        3.00
# 9     Albany  42.6001  -73.9662     67.32        84          90        5.59
#
#   Country Current Description
# 0      ID     overcast clouds
# 1      PF       broken clouds
# 2      US          light rain
# 3      NZ          light rain
# 4      AU    scattered clouds
# 5      NO    scattered clouds
# 6      KZ    scattered clouds
# 7      JP       broken clouds
# 8      US           clear sky
# 9      US     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Bengkulu      ID  -3.8004  102.2655     85.44        62          99
# 1     Faanui      PF -16.4833 -151.7500     80.38        78          81
# 2       Hilo      US  19.7297 -155.0900     76.28        85          90
# 3    Waipawa      NZ -41.4122  175.5153     56.03        88         100
# 4  Geraldton      AU -28.7667  114.6000     70.21        64          40
# 5      Vardo      NO  70.3705   31.1107     52.00        71          40
# 6  Kushmurun      KZ  52.4503   64.6311     80.69        30          27
# 7   Sueyoshi      JP  31.6500  131.0167     81.57        75          81
# 8   Evanston      US  42.0411  -87.6901     74.97        51           1
# 9     Albany      US  42.6001  -73.9662     67.32        84          90
#
#    Wind Speed Current Description
# 0        6.55     overcast clouds
# 1       15.37       broken clouds
# 2        4.61          light rain
# 3        5.68          light rain
# 4       18.41    scattered clouds
# 5        4.61    scattered clouds
# 6        2.33    scattered clouds
# 7        5.79       broken clouds
# 8        3.00           clear sky
# 9        5.59     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
